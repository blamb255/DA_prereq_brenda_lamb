# %%
print("Hi. I certainly hope that everyone else had an easier time with this than me! I have definitely got to spend time practicing git!! ")

# %% [markdown]
# print( "Hi! I'm Brenda. I'm very excited to practice more on this and learn more about it! I definitely have got to do the git practice in the resources.")
